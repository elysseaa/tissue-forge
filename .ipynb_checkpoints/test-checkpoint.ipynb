# %%
import particleModifier_flat
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import particleModifier
#
# File ~\OneDrive\Documents\Projects\tissue-forge-updatedfeatures\wraps\python\notebook\particleModifier.py:5
#       3 import tissue_forge as tf
#       4 import numpy as np
# ----> 5 from . import widgets as tfnw
#       6 from typing import Any, Dict
#       8 LABELTEXT_PTYPE_COLOR = 'Color for type '
#
# ImportError: attempted relative import with no known parent package

# %%
pip install ipywidgets
# Out:
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 1.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 1.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.2 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 1.4 MB/s eta 0:00:00
# ...
#
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipyevents
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
