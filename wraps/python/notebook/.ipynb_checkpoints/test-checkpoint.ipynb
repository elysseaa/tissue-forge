# %%
# %load_ext autoreload
# %autoreload 2
import tissue_forge as tf
import numpy as np

# %%
# %reload_ext autoreload

# %%
# dimensions of universe
dim = [10., 10., 10.]

# new simulator
tf.init(dim=dim, bc=5)

# %%
# dir()
dir(tf)
dir(tf.BoundaryConditions)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__swig_destroy__',
#  '__weakref__',
#  'back',
#  'bottom',
#  'boundaryKindFromString',
#  'boundaryKindFromStrings',
#  'bounded_position',
#  'fromString',
#  'front',
#  'left',
#  'periodic',
#  'potenntials',
#  'right',
#  'set_potential',
#  'str',
#  'thisown',
#  'toString',
#  'top']

# %%
from sim_init import *

init(show=True)
# Out:
# Output()
# ...

# %%
data = {'dim': [-7.0, -13.0, -12.0]}
tf.init(**data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 data = {'dim': [-7.0, -13.0, -12.0]}
# ----> 2 tf.init(**data)
#
# NameError: name 'tf' is not defined

# %%
test_data = {'dim': [1,1,1], "load_file":"'"}
tf.init(**test_data)

# %%
tf.FVector3
# Out:
# tissue_forge.tissue_forge.fVector3

# %%
from saveandscreenshot import *
save_widget()
# Out:
# Output()
# (Button(button_style='info', description='Save simulation', style=ButtonStyle(), tooltip='Save a simulation to file'),
#  Output())

# %%
tf.BoundaryTypeFlags
for color_member in tf.BoundaryTypeFlags:
    print(color_member)
    print(color_member.value)
# Out:
# BoundaryTypeFlags.none
# 0
# BoundaryTypeFlags.periodic_x
# 1
# BoundaryTypeFlags.periodic_y
# 2
# BoundaryTypeFlags.periodic_z
# 4
# BoundaryTypeFlags.periodic
# 7
# BoundaryTypeFlags.ghost_x
# 8
# BoundaryTypeFlags.ghost_y
# 16
# BoundaryTypeFlags.ghost_z
# 32
# BoundaryTypeFlags.ghost
# 56
# BoundaryTypeFlags.freeslip_x
# 64
# BoundaryTypeFlags.freeslip_y
# 128
# BoundaryTypeFlags.freeslip_z
# 256
# BoundaryTypeFlags.freeslip
# 448

# %%
from background_widgets import *

box, r, g, b = set_background_text()
box

# %%
from particleModifier import *

class ptype(tf.ParticleTypeSpec):
    mass = 40
    radius = 0.4
    dynamics = tf.Overdamped
    style = {'color': 'red'}

ptype = ptype.get()

# Create and show a widget to modify the color of a particle type and its particles
set_ptype_number_text(ptype, show=True, min=500, max=1000)
# Out:
# ...
# (HBox(children=(IntText(value=0, description='Particle # for type ptype', step=5),)),
#  IntText(value=0, description='Particle # for type ptype', step=5))

# %%
# create a potential representing a 12-6 Lennard-Jones potential
pot = tf.Potential.lennard_jones_12_6(0.275, 3.0, 9.5075e-06, 6.1545e-03, 1.0e-3)


# create a particle type
class ArgonType(tf.ParticleTypeSpec):
    radius = 0.1
    mass = 39.4


# Register and get the particle type; registration always only occurs once
Argon = ArgonType.get()

# bind the potential with the *TYPES* of the particles
tf.bind.types(pot, Argon, Argon)

# uniform random cube
positions = np.random.uniform(low=0, high=10, size=(10000, 3))

for pos in positions:
    # calling the particle constructor implicitly adds
    # the particle to the universe
    Argon(pos)

# run the simulator interactive
tf.run()

# %%
tf.show()

# %%
tf.run()
tf.show()
